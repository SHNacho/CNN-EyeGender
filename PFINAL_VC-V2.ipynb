# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/MyDrive/eyes.zip" -d "/content/eyes"

# %%
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import load_img,img_to_array
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU, AveragePooling2D
from keras.layers import BatchNormalization, Activation
#from sklearn.model_selection import train_test_split
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import DenseNet121, DenseNet169, DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input


import pandas as pd
from glob import glob
import cv2
from tqdm import tqdm
import os

print(tf.__version__)
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-lxml33y2 because the default path (/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# 2.7.0

# %%
# Constantes para el resto del programa
image_size = 75
channels = 3
seed = 1

batch_size = 32
validation_split = 0.1
test_size = 0.2

# %%
def mostrarEvolucion(hist):
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    pyplot.plot(loss)
    pyplot.plot(val_loss)
    pyplot.legend(['Training loss', 'Validation loss'])
    pyplot.show()

    acc = hist.history['accuracy']
    val_acc = hist.history['val_accuracy']
    pyplot.plot(acc)
    pyplot.plot(val_acc)
    pyplot.legend(['Training accuracy','Validation accuracy'])
    pyplot.show()

# %%
PATH = "./eyes/"
train_dir = os.path.join(PATH)
# Coge las imagenes por lotes, el tamaño por defecto del lote es de 32
train = tf.keras.utils.image_dataset_from_directory(
        train_dir,
        validation_split=(0.3),
        subset="training",
        seed=42,
        image_size=(image_size,image_size)
    )
validation = tf.keras.utils.image_dataset_from_directory(
        train_dir,
        validation_split=(0.3),
        subset="validation",
        seed=42,
        image_size=(image_size,image_size)
    )
# Out:
# Found 11525 files belonging to 2 classes.
# Using 8068 files for training.
# Found 11525 files belonging to 2 classes.
# Using 3457 files for validation.

# %%
plt.figure(figsize=(10,10))
for images,labels in train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(train.class_names[labels[i]])
        plt.axis(False)
plt.show()

# %%
# Obtenemos el número de lotes iniciales para validación (el 30% del total)
val_batches = tf.data.experimental.cardinality(validation)
# Nos quedamos con 2/3 de esos lotes para test (el 20% del total)
test_batches = int( float(val_batches) * (2/3) )
test = validation.take(test_batches)
# Quitamos esos 2/3 de la validación para quedarnos con un 10% en validación 
# y 20% en test
validation = validation.skip(test_batches)

print('Número de lotes de validación: %d' % tf.data.experimental.cardinality(validation))
print('Número de lotes de test: %d' % tf.data.experimental.cardinality(test))
# Out:
# Número de lotes de validación: 37
# Número de lotes de test: 72

# %%
def cargaDenseNet(dense_type = 'densenet121'):
    densenet = None
    if(dense_type == 'densenet121'):
        densenet = DenseNet121(
            input_shape=(image_size, image_size, channels),
            include_top = False,
            weights="imagenet",
            pooling="avg"
        ) 
    elif(dense_type == 'densenet169'):
        densenet = DenseNet169(
            input_shape=(image_size, image_size, channels),
            include_top = False,
            weights="imagenet",
            pooling="avg"
        ) 
    elif(dense_type == 'densenet201'):
        densenet = DenseNet201(
            input_shape=(image_size, image_size, channels),
            include_top = False,
            weights="imagenet",
            pooling="avg"
        )
    return densenet

# %% [markdown]
# ## Trasfer learning solo con una capa de clasificación

# %%
def model_frozen_only_classifier(epochs, dense_type):

    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False

    inputs = keras.Input(shape=(image_size,image_size,channels))
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)

    model.summary()

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train,
        epochs = epochs,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')

    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del model, score, hist, densenet

# %%
model_frozen_only_classifier(10, 'densenet121')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 35s 78ms/step - loss: 0.4423 - accuracy: 0.8016 - val_loss: 0.2941 - val_accuracy: 0.8838
# Epoch 2/10
# 253/253 [==============================] - 17s 65ms/step - loss: 0.2812 - accuracy: 0.8814 - val_loss: 0.2922 - val_accuracy: 0.8647
# Epoch 3/10
# 253/253 [==============================] - 17s 66ms/step - loss: 0.2499 - accuracy: 0.8990 - val_loss: 0.2959 - val_accuracy: 0.8656
# Epoch 4/10
# 253/253 [==============================] - 17s 65ms/step - loss: 0.2319 - accuracy: 0.9056 - val_loss: 0.2471 - val_accuracy: 0.8864
# Epoch 5/10
# 253/253 [==============================] - 17s 65ms/step - loss: 0.2214 - accuracy: 0.9114 - val_loss: 0.2537 - val_accuracy: 0.8794
# Epoch 6/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2110 - accuracy: 0.9175 - val_loss: 0.2614 - val_accuracy: 0.8864
# Epoch 7/10
# 253/253 [==============================] - 16s 64ms/step - loss: 0.2049 - accuracy: 0.9187 - val_loss: 0.2244 - val_accuracy: 0.9011
# Epoch 8/10
# 253/253 [==============================] - 16s 63ms/step - loss: 0.1985 - accuracy: 0.9212 - val_loss: 0.2192 - val_accuracy: 0.9098
# Epoch 9/10
# 253/253 [==============================] - 16s 63ms/step - loss: 0.1943 - accuracy: 0.9241 - val_loss: 0.2157 - val_accuracy: 0.9011
# Epoch 10/10
# 253/253 [==============================] - 16s 63ms/step - loss: 0.1906 - accuracy: 0.9250 - val_loss: 0.2079 - val_accuracy: 0.9133
# RESULTADOS EN TEST:
# Pérdida en test: 0.23123663663864136
# Accuracy en test: 0.9066840410232544

# %%
model_frozen_only_classifier(10, 'densenet169')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 0s 0us/step
# 51888128/51877672 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_3 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dense_1 (Dense)             (None, 1)                 1665
#
# =================================================================
# Total params: 12,644,545
# Trainable params: 1,665
# Non-trainable params: 12,642,880
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 35s 96ms/step - loss: 0.4250 - accuracy: 0.8083 - val_loss: 0.2738 - val_accuracy: 0.8812
# Epoch 2/10
# 253/253 [==============================] - 21s 82ms/step - loss: 0.2758 - accuracy: 0.8872 - val_loss: 0.2715 - val_accuracy: 0.8760
# Epoch 3/10
# 253/253 [==============================] - 21s 81ms/step - loss: 0.2436 - accuracy: 0.9033 - val_loss: 0.2365 - val_accuracy: 0.9046
# Epoch 4/10
# 253/253 [==============================] - 21s 82ms/step - loss: 0.2240 - accuracy: 0.9094 - val_loss: 0.2746 - val_accuracy: 0.8760
# Epoch 5/10
# 253/253 [==============================] - 21s 82ms/step - loss: 0.2132 - accuracy: 0.9158 - val_loss: 0.2352 - val_accuracy: 0.9020
# Epoch 6/10
# 253/253 [==============================] - 21s 82ms/step - loss: 0.2035 - accuracy: 0.9208 - val_loss: 0.2543 - val_accuracy: 0.8881
# Epoch 7/10
# 253/253 [==============================] - 21s 82ms/step - loss: 0.1999 - accuracy: 0.9213 - val_loss: 0.2234 - val_accuracy: 0.9124
# Epoch 8/10
# 253/253 [==============================] - 21s 82ms/step - loss: 0.1981 - accuracy: 0.9204 - val_loss: 0.2224 - val_accuracy: 0.9063
# Epoch 9/10
# 253/253 [==============================] - 21s 84ms/step - loss: 0.1880 - accuracy: 0.9234 - val_loss: 0.2197 - val_accuracy: 0.9089
# Epoch 10/10
# 253/253 [==============================] - 21s 83ms/step - loss: 0.1844 - accuracy: 0.9279 - val_loss: 0.2262 - val_accuracy: 0.9115
# RESULTADOS EN TEST:
# Pérdida en test: 0.21766424179077148
# Accuracy en test: 0.9175347089767456

# %%
model_frozen_only_classifier(10,'densenet201')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_4 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.nn.bias_add_2 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_5 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  dense_2 (Dense)             (None, 1)                 1921
#
# =================================================================
# Total params: 18,323,905
# Trainable params: 1,921
# Non-trainable params: 18,321,984
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 43s 116ms/step - loss: 0.3633 - accuracy: 0.8417 - val_loss: 0.3349 - val_accuracy: 0.8621
# Epoch 2/10
# 253/253 [==============================] - 25s 98ms/step - loss: 0.2665 - accuracy: 0.8911 - val_loss: 0.2639 - val_accuracy: 0.8916
# Epoch 3/10
# 253/253 [==============================] - 25s 99ms/step - loss: 0.2345 - accuracy: 0.9068 - val_loss: 0.2459 - val_accuracy: 0.8994
# Epoch 4/10
# 253/253 [==============================] - 25s 100ms/step - loss: 0.2158 - accuracy: 0.9148 - val_loss: 0.2280 - val_accuracy: 0.9115
# Epoch 5/10
# 253/253 [==============================] - 25s 99ms/step - loss: 0.2084 - accuracy: 0.9176 - val_loss: 0.2408 - val_accuracy: 0.9046
# Epoch 6/10
# 253/253 [==============================] - 25s 99ms/step - loss: 0.2020 - accuracy: 0.9193 - val_loss: 0.2217 - val_accuracy: 0.9055
# Epoch 7/10
# 253/253 [==============================] - 25s 99ms/step - loss: 0.1892 - accuracy: 0.9258 - val_loss: 0.2361 - val_accuracy: 0.9020
# Epoch 8/10
# 253/253 [==============================] - 25s 99ms/step - loss: 0.1846 - accuracy: 0.9279 - val_loss: 0.2433 - val_accuracy: 0.9020
# Epoch 9/10
# 253/253 [==============================] - 25s 99ms/step - loss: 0.1791 - accuracy: 0.9298 - val_loss: 0.2368 - val_accuracy: 0.9055
# Epoch 10/10
# 253/253 [==============================] - 25s 99ms/step - loss: 0.1758 - accuracy: 0.9329 - val_loss: 0.2255 - val_accuracy: 0.9072
# RESULTADOS EN TEST:
# Pérdida en test: 0.2153015434741974
# Accuracy en test: 0.9157986044883728

# %% [markdown]
# ## Transfer learning con clasificador y data augmentation
# Ahora comprobaremos como mejora el entrenamiento y la predicción al realizar *data augmentation*

# %%
def model_frozen_only_classifier_data_augmentation(epochs, dense_type):

    # Generamos una capa de aumento de datos
    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
    ])

    # map aplica la función pasada como primer argumento a todos los elemetos
    # del dataset y devuelve un nuevo dataset que contiene los elementos
    # transformados
    train_aug = train.map(lambda x, y: (data_augmentation(x, training=True), y))

    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False

    inputs = keras.Input(shape=(image_size,image_size,channels))
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = epochs,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')

    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del model, score, hist, densenet

# %%
model_frozen_only_classifier_data_augmentation(10, 'densenet121')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# Epoch 1/10
# 253/253 [==============================] - 46s 115ms/step - loss: 0.4156 - accuracy: 0.8223 - val_loss: 0.2973 - val_accuracy: 0.8812
# Epoch 2/10
# 253/253 [==============================] - 23s 92ms/step - loss: 0.3015 - accuracy: 0.8763 - val_loss: 0.2890 - val_accuracy: 0.8725
# Epoch 3/10
# 253/253 [==============================] - 26s 102ms/step - loss: 0.2786 - accuracy: 0.8841 - val_loss: 0.3754 - val_accuracy: 0.8213
# Epoch 4/10
# 253/253 [==============================] - 23s 92ms/step - loss: 0.2582 - accuracy: 0.8939 - val_loss: 0.2748 - val_accuracy: 0.8786
# Epoch 5/10
# 253/253 [==============================] - 26s 102ms/step - loss: 0.2606 - accuracy: 0.8940 - val_loss: 0.2403 - val_accuracy: 0.9029
# Epoch 6/10
# 253/253 [==============================] - 23s 91ms/step - loss: 0.2401 - accuracy: 0.9006 - val_loss: 0.2512 - val_accuracy: 0.8968
# Epoch 7/10
# 253/253 [==============================] - 26s 101ms/step - loss: 0.2504 - accuracy: 0.8982 - val_loss: 0.2455 - val_accuracy: 0.8985
# Epoch 8/10
# 253/253 [==============================] - 23s 91ms/step - loss: 0.2416 - accuracy: 0.8997 - val_loss: 0.2308 - val_accuracy: 0.9037
# Epoch 9/10
# 253/253 [==============================] - 25s 98ms/step - loss: 0.2365 - accuracy: 0.9072 - val_loss: 0.2261 - val_accuracy: 0.9055
# Epoch 10/10
# 253/253 [==============================] - 23s 92ms/step - loss: 0.2376 - accuracy: 0.9062 - val_loss: 0.2214 - val_accuracy: 0.9098
# RESULTADOS EN TEST:
# Pérdida en test: 0.24156342446804047
# Accuracy en test: 0.90234375

# %%
model_frozen_only_classifier_data_augmentation(10, 'densenet169')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 0s 0us/step
# 51888128/51877672 [==============================] - 0s 0us/step
# Epoch 1/10
# 253/253 [==============================] - 43s 126ms/step - loss: 0.4330 - accuracy: 0.8080 - val_loss: 0.2864 - val_accuracy: 0.8873
# Epoch 2/10
# 253/253 [==============================] - 27s 108ms/step - loss: 0.2920 - accuracy: 0.8775 - val_loss: 0.3075 - val_accuracy: 0.8612
# Epoch 3/10
# 253/253 [==============================] - 27s 108ms/step - loss: 0.2717 - accuracy: 0.8875 - val_loss: 0.2716 - val_accuracy: 0.8864
# Epoch 4/10
# 253/253 [==============================] - 28s 108ms/step - loss: 0.2542 - accuracy: 0.8959 - val_loss: 0.2860 - val_accuracy: 0.8777
# Epoch 5/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2426 - accuracy: 0.9020 - val_loss: 0.2684 - val_accuracy: 0.8846
# Epoch 6/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2437 - accuracy: 0.9006 - val_loss: 0.2706 - val_accuracy: 0.8760
# Epoch 7/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2359 - accuracy: 0.9029 - val_loss: 0.2395 - val_accuracy: 0.8942
# Epoch 8/10
# 253/253 [==============================] - 27s 108ms/step - loss: 0.2389 - accuracy: 0.9042 - val_loss: 0.2609 - val_accuracy: 0.8907
# Epoch 9/10
# 253/253 [==============================] - 27s 108ms/step - loss: 0.2318 - accuracy: 0.9036 - val_loss: 0.2577 - val_accuracy: 0.8899
# Epoch 10/10
# 253/253 [==============================] - 27s 108ms/step - loss: 0.2276 - accuracy: 0.9079 - val_loss: 0.2259 - val_accuracy: 0.9011
# RESULTADOS EN TEST:
# Pérdida en test: 0.22279092669487
# Accuracy en test: 0.9118923544883728

# %%
model_frozen_only_classifier_data_augmentation(10, 'densenet201')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# Epoch 1/10
# 253/253 [==============================] - 49s 140ms/step - loss: 0.4064 - accuracy: 0.8163 - val_loss: 0.3786 - val_accuracy: 0.8257
# Epoch 2/10
# 100/253 [==========>...................] - ETA: 16s - loss: 0.3247 - accuracy: 0.8594

# %% [markdown]
# ## Fine tuning - Adam
# A continuación realizaremos fine-tuning partiendo de la red anterior, con data augmentation. Para ello partinermos de la red anterior y descongelaremos el último bloque denso.
#
# Para el aumento de datos se aplicarán las transformaciones de giro horizontal y rotación.
#
# Al estar trabajando con datasets de tensorflow que funcionan generando batches, para aplicar aumento de datos, lo haremos usando el método `dataset.map` solo sobre el dataset de train, para que las transformaciones solo se apliquen a este. Esto nos devolverá un nuevo generador de lotes (`dataset`) que aplicará las transformaciones a las imágenes que genere.
#
# Para realizar fine-tuning:
# 1. Se entrenará SOLO la capa de clasificación durante unas pocas épocas
# 2. Se descongelará el último bloque denso de la red DenseNet, el cual contiene todas las capas en las que aparezaca 'conv5'
# 3. Se volverá a entrenar el modelo comenzando por la época en la que terminó el entrenamiento del clasificador del punto 1

# %%
def model_defrost_conv5_data_augmentation(epochs_frozen, epochs_defrost, dense_type):
    
    # Generamos una capa de aumento de datos
    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
    ])
    
    # map aplica la función pasada como primer argumento a todos los elemetos
    # del dataset y devuelve un nuevo dataset que contiene los elementos
    # transformados
    train_aug = train.map(lambda x, y: (data_augmentation(x, training=True), y))
        
    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False
    
    #densenet.summary()

    inputs = keras.Input(shape=(image_size,image_size,channels))
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)
    model.summary()

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train_aug,
        epochs = epochs_frozen,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del score
    
    total_epochs = epochs_frozen + epochs_defrost

    my_layer = model.get_layer(dense_type)
    my_layer.trainable = True

    for layer in my_layer.layers:
        print(layer.name)
        if 'conv5' in layer.name:
            layer.trainable = True
        else:
            layer.trainable = False

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(2e-5),
        metrics=["accuracy"]
    )

    model.summary()

    hist_fine = model.fit(
        train,
        epochs = total_epochs,
        initial_epoch = hist.epoch[-1],
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist_fine)

    print('RESULTADOS EN TEST:')

    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])


    del model, score, hist, densenet, hist_fine

# %%
model_defrost_conv5_data_augmentation(10, 10, 'densenet121')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 44s 111ms/step - loss: 0.4243 - accuracy: 0.8052 - val_loss: 0.3312 - val_accuracy: 0.8534
# Epoch 2/10
# 253/253 [==============================] - 23s 90ms/step - loss: 0.2990 - accuracy: 0.8782 - val_loss: 0.3039 - val_accuracy: 0.8656
# Epoch 3/10
# 253/253 [==============================] - 28s 110ms/step - loss: 0.2794 - accuracy: 0.8861 - val_loss: 0.3716 - val_accuracy: 0.8257
# Epoch 4/10
# 253/253 [==============================] - 23s 90ms/step - loss: 0.2670 - accuracy: 0.8911 - val_loss: 0.2887 - val_accuracy: 0.8664
# Epoch 5/10
# 253/253 [==============================] - 25s 100ms/step - loss: 0.2598 - accuracy: 0.8928 - val_loss: 0.2807 - val_accuracy: 0.8734
# Epoch 6/10
# 253/253 [==============================] - 23s 90ms/step - loss: 0.2475 - accuracy: 0.8986 - val_loss: 0.2889 - val_accuracy: 0.8734
# Epoch 7/10
# 253/253 [==============================] - 25s 98ms/step - loss: 0.2375 - accuracy: 0.9038 - val_loss: 0.2471 - val_accuracy: 0.8907
# Epoch 8/10
# 253/253 [==============================] - 23s 90ms/step - loss: 0.2417 - accuracy: 0.9033 - val_loss: 0.2354 - val_accuracy: 0.9020
# Epoch 9/10
# 253/253 [==============================] - 25s 97ms/step - loss: 0.2378 - accuracy: 0.9031 - val_loss: 0.2330 - val_accuracy: 0.8933
# Epoch 10/10
# 253/253 [==============================] - 23s 91ms/step - loss: 0.2364 - accuracy: 0.9008 - val_loss: 0.2335 - val_accuracy: 0.8907
# RESULTADOS EN TEST:
# Pérdida en test: 0.24996274709701538
# Accuracy en test: 0.8993055820465088
# input_1
# zero_padding2d
# conv1/conv
# conv1/bn
# conv1/relu
# zero_padding2d_1
# pool1
# conv2_block1_0_bn
# conv2_block1_0_relu
# conv2_block1_1_conv
# conv2_block1_1_bn
# conv2_block1_1_relu
# conv2_block1_2_conv
# conv2_block1_concat
# conv2_block2_0_bn
# conv2_block2_0_relu
# conv2_block2_1_conv
# conv2_block2_1_bn
# conv2_block2_1_relu
# conv2_block2_2_conv
# conv2_block2_concat
# conv2_block3_0_bn
# conv2_block3_0_relu
# conv2_block3_1_conv
# conv2_block3_1_bn
# conv2_block3_1_relu
# conv2_block3_2_conv
# conv2_block3_concat
# conv2_block4_0_bn
# conv2_block4_0_relu
# conv2_block4_1_conv
# conv2_block4_1_bn
# conv2_block4_1_relu
# conv2_block4_2_conv
# conv4_block3_1_conv
# conv4_block3_1_bn
# conv4_block3_1_relu
# conv4_block3_2_conv
# conv4_block3_concat
# conv4_block4_0_bn
# conv4_block4_0_relu
# conv4_block4_1_conv
# conv4_block4_1_bn
# conv4_block4_1_relu
# conv4_block4_2_conv
# conv4_block4_concat
# conv4_block5_0_bn
# conv4_block5_0_relu
# conv4_block5_1_conv
# conv4_block5_1_bn
# conv4_block5_1_relu
# conv4_block5_2_conv
# conv4_block5_concat
# conv4_block6_0_bn
# conv4_block6_0_relu
# conv4_block6_1_conv
# conv4_block6_1_bn
# conv4_block6_1_relu
# conv4_block6_2_conv
# conv4_block6_concat
# conv4_block7_0_bn
# conv4_block7_0_relu
# conv4_block7_1_conv
# conv4_block7_1_bn
# conv4_block7_1_relu
# conv4_block7_2_conv
# conv4_block7_concat
# conv4_block8_0_bn
# conv4_block8_0_relu
# conv4_block8_1_conv
# conv4_block8_1_bn
# conv4_block8_1_relu
# conv4_block8_2_conv
# conv4_block8_concat
# conv4_block9_0_bn
# conv4_block9_0_relu
# conv4_block9_1_conv
# conv4_block9_1_bn
# conv4_block9_1_relu
# conv4_block9_2_conv
# conv4_block9_concat
# conv4_block10_0_bn
# conv4_block10_0_relu
# conv4_block10_1_conv
# conv4_block10_1_bn
# conv4_block10_1_relu
# conv4_block10_2_conv
# conv4_block10_concat
# conv4_block11_0_bn
# conv4_block11_0_relu
# conv4_block11_1_conv
# conv4_block11_1_bn
# conv4_block11_1_relu
# conv4_block11_2_conv
# conv4_block11_concat
# conv4_block12_0_bn
# conv4_block12_0_relu
# conv4_block12_1_conv
# conv4_block12_1_bn
# conv4_block12_1_relu
# conv4_block12_2_conv
# conv4_block12_concat
# conv4_block13_0_bn
# conv4_block13_0_relu
# conv4_block13_1_conv
# conv4_block13_1_bn
# conv4_block13_1_relu
# conv4_block13_2_conv
# conv4_block13_concat
# conv4_block14_0_bn
# conv4_block14_0_relu
# conv4_block14_1_conv
# conv4_block14_1_bn
# conv4_block14_1_relu
# conv4_block14_2_conv
# conv4_block14_concat
# conv4_block15_0_bn
# conv4_block15_0_relu
# conv4_block15_1_conv
# conv4_block15_1_bn
# conv4_block15_1_relu
# conv4_block15_2_conv
# conv4_block15_concat
# conv4_block16_0_bn
# conv4_block16_0_relu
# conv4_block16_1_conv
# conv4_block16_1_bn
# conv4_block16_1_relu
# conv4_block16_2_conv
# conv4_block16_concat
# conv4_block17_0_bn
# conv4_block17_0_relu
# conv4_block17_1_conv
# conv4_block17_1_bn
# conv4_block17_1_relu
# conv4_block17_2_conv
# conv4_block17_concat
# conv4_block18_0_bn
# conv4_block18_0_relu
# conv4_block18_1_conv
# conv4_block18_1_bn
# conv4_block18_1_relu
# conv4_block18_2_conv
# conv4_block18_concat
# conv4_block19_0_bn
# conv4_block19_0_relu
# conv4_block19_1_conv
# conv4_block19_1_bn
# conv4_block19_1_relu
# conv4_block19_2_conv
# conv4_block19_concat
# conv4_block20_0_bn
# conv4_block20_0_relu
# conv4_block20_1_conv
# conv4_block20_1_bn
# conv4_block20_1_relu
# conv4_block20_2_conv
# conv4_block20_concat
# conv4_block21_0_bn
# conv4_block21_0_relu
# conv4_block21_1_conv
# conv4_block21_1_bn
# conv4_block21_1_relu
# conv4_block21_2_conv
# conv4_block21_concat
# conv4_block22_0_bn
# conv4_block22_0_relu
# conv4_block22_1_conv
# conv4_block22_1_bn
# conv4_block22_1_relu
# conv4_block22_2_conv
# conv4_block22_concat
# conv4_block23_0_bn
# conv4_block23_0_relu
# conv4_block23_1_conv
# conv4_block23_1_bn
# conv4_block23_1_relu
# conv4_block23_2_conv
# conv4_block23_concat
# conv4_block24_0_bn
# conv4_block24_0_relu
# conv4_block24_1_conv
# conv4_block24_1_bn
# conv4_block24_1_relu
# conv4_block24_2_conv
# conv4_block24_concat
# pool4_bn
# pool4_relu
# pool4_conv
# pool4_pool
# conv5_block1_0_bn
# conv5_block1_0_relu
# conv5_block1_1_conv
# conv5_block1_1_bn
# conv5_block1_1_relu
# conv5_block1_2_conv
# conv5_block1_concat
# conv5_block2_0_bn
# conv5_block2_0_relu
# conv5_block2_1_conv
# conv5_block2_1_bn
# conv5_block2_1_relu
# conv5_block2_2_conv
# conv5_block2_concat
# conv5_block3_0_bn
# conv5_block3_0_relu
# conv5_block3_1_conv
# conv5_block3_1_bn
# conv5_block3_1_relu
# conv5_block3_2_conv
# conv5_block3_concat
# conv5_block4_0_bn
# conv5_block4_0_relu
# conv5_block4_1_conv
# conv5_block4_1_bn
# conv5_block4_1_relu
# conv5_block4_2_conv
# conv5_block4_concat
# conv5_block5_0_bn
# conv5_block5_0_relu
# conv5_block5_1_conv
# conv5_block5_1_bn
# conv5_block5_1_relu
# conv5_block5_2_conv
# conv5_block5_concat
# conv5_block6_0_bn
# conv5_block6_0_relu
# conv5_block6_1_conv
# conv5_block6_1_bn
# conv5_block6_1_relu
# conv5_block6_2_conv
# conv5_block6_concat
# conv5_block7_0_bn
# conv5_block7_0_relu
# conv5_block7_1_conv
# conv5_block7_1_bn
# conv5_block7_1_relu
# conv5_block7_2_conv
# conv5_block7_concat
# conv5_block8_0_bn
# conv5_block8_0_relu
# conv5_block8_1_conv
# conv5_block8_1_bn
# conv5_block8_1_relu
# conv5_block8_2_conv
# conv5_block8_concat
# conv5_block9_0_bn
# conv5_block9_0_relu
# conv5_block9_1_conv
# conv5_block9_1_bn
# conv5_block9_1_relu
# conv5_block9_2_conv
# conv5_block9_concat
# conv5_block10_0_bn
# conv5_block10_0_relu
# conv5_block10_1_conv
# conv5_block10_1_bn
# conv5_block10_1_relu
# conv5_block10_2_conv
# conv5_block10_concat
# conv5_block11_0_bn
# conv5_block11_0_relu
# conv5_block11_1_conv
# conv5_block11_1_bn
# conv5_block11_1_relu
# conv5_block11_2_conv
# conv5_block11_concat
# conv5_block12_0_bn
# conv5_block12_0_relu
# conv5_block12_1_conv
# conv5_block12_1_bn
# conv5_block12_1_relu
# conv5_block12_2_conv
# conv5_block12_concat
# conv5_block13_0_bn
# conv5_block13_0_relu
# conv5_block13_1_conv
# conv5_block13_1_bn
# conv5_block13_1_relu
# conv5_block13_2_conv
# conv5_block13_concat
# conv5_block14_0_bn
# conv5_block14_0_relu
# conv5_block14_1_conv
# conv5_block14_1_bn
# conv5_block14_1_relu
# conv5_block14_2_conv
# conv5_block14_concat
# conv5_block15_0_bn
# conv5_block15_0_relu
# conv5_block15_1_conv
# conv5_block15_1_bn
# conv5_block15_1_relu
# conv5_block15_2_conv
# conv5_block15_concat
# conv5_block16_0_bn
# conv5_block16_0_relu
# conv5_block16_1_conv
# conv5_block16_1_bn
# conv5_block16_1_relu
# conv5_block16_2_conv
# conv5_block16_concat
# bn
# relu
# avg_pool
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 2,159,105
# Non-trainable params: 4,879,424
# _________________________________________________________________
# Epoch 10/20
# 253/253 [==============================] - 34s 94ms/step - loss: 0.1998 - accuracy: 0.9183 - val_loss: 0.2027 - val_accuracy: 0.9185
# Epoch 11/20
# 253/253 [==============================] - 22s 85ms/step - loss: 0.1545 - accuracy: 0.9373 - val_loss: 0.1896 - val_accuracy: 0.9202
# Epoch 12/20
# 253/253 [==============================] - 22s 85ms/step - loss: 0.1256 - accuracy: 0.9515 - val_loss: 0.1894 - val_accuracy: 0.9202
# Epoch 13/20
# 253/253 [==============================] - 22s 85ms/step - loss: 0.1042 - accuracy: 0.9633 - val_loss: 0.1900 - val_accuracy: 0.9219
# Epoch 14/20
# 253/253 [==============================] - 21s 85ms/step - loss: 0.0883 - accuracy: 0.9681 - val_loss: 0.1832 - val_accuracy: 0.9237
# Epoch 15/20
# 253/253 [==============================] - 22s 85ms/step - loss: 0.0739 - accuracy: 0.9762 - val_loss: 0.1693 - val_accuracy: 0.9289
# Epoch 16/20
# 253/253 [==============================] - 21s 84ms/step - loss: 0.0653 - accuracy: 0.9808 - val_loss: 0.1734 - val_accuracy: 0.9306
# Epoch 17/20
# 253/253 [==============================] - 22s 86ms/step - loss: 0.0555 - accuracy: 0.9841 - val_loss: 0.1686 - val_accuracy: 0.9280
# Epoch 18/20
# 253/253 [==============================] - 22s 85ms/step - loss: 0.0445 - accuracy: 0.9891 - val_loss: 0.1640 - val_accuracy: 0.9358
# Epoch 19/20
# 253/253 [==============================] - 21s 83ms/step - loss: 0.0349 - accuracy: 0.9939 - val_loss: 0.1893 - val_accuracy: 0.9384
# Epoch 20/20
# 253/253 [==============================] - 21s 84ms/step - loss: 0.0302 - accuracy: 0.9949 - val_loss: 0.1916 - val_accuracy: 0.9315
# RESULTADOS EN TEST:
# Pérdida en test: 0.18454168736934662
# Accuracy en test: 0.9361979365348816

# %%
model_defrost_conv5_data_augmentation(10, 10, 'densenet169')
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_16 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  tf.nn.bias_add_8 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_17 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dense_8 (Dense)             (None, 1)                 1665
#
# =================================================================
# Total params: 12,644,545
# Trainable params: 1,665
# Non-trainable params: 12,642,880
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] -
# 253/253 [==============================] - 17s 69ms/step - loss: 0.0248 - accuracy: 0.9955 - val_loss: 0.1562 - val_accuracy: 0.9393
# Epoch 16/20
# 253/253 [==============================] - 17s 68ms/step - loss: 0.0155 - accuracy: 0.9985 - val_loss: 0.2419 - val_accuracy: 0.9150
# Epoch 17/20
# 253/253 [==============================] - 17s 68ms/step - loss: 0.0159 - accuracy: 0.9976 - val_loss: 0.1926 - val_accuracy: 0.9350
# Epoch 18/20
# 253/253 [==============================] - 17s 68ms/step - loss: 0.0070 - accuracy: 0.9998 - val_loss: 0.1761 - val_accuracy: 0.9462
# Epoch 19/20
# 253/253 [==============================] - 17s 69ms/step - loss: 0.0065 - accuracy: 0.9998 - val_loss: 0.1825 - val_accuracy: 0.9462
# Epoch 20/20
# 253/253 [==============================] - 17s 69ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9402
# RESULTADOS EN TEST:
# Pérdida en test: 0.17965926229953766
# Accuracy en test: 0.9470486044883728

# %%
def model_defrost_conv5_data_augmentation_lr(epochs_frozen, epochs_defrost, dense_type):

    ############################################################
    ### Transfer learning
    ############################################################
    lr = 0.0001
    
    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
    ])

    # map aplica la función pasada como primer argumento a todos los elemetos
    # del dataset y devuelve un nuevo dataset que contiene los elementos
    # transformados
    train_aug = train.map(lambda x, y: (data_augmentation(x, training=True), y))
    
    # for image, _ in train.take(1):
    #     plt.figure(figsize=(10, 10))
    #     first_image = image[0]
    #     for i in range(9):
    #         ax = plt.subplot(3, 3, i + 1)
    #         augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    #         plt.imshow(augmented_image[0] / 255)
    #         plt.axis('off')
        
    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False

    inputs = keras.Input(shape=(image_size,image_size,3))
    #x = data_augmentation(inputs)
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)
    model.summary()

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = epochs_frozen,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del score

    ############################################################
    ### Fine-tuning
    ############################################################

    total_epochs = epochs_frozen + epochs_defrost

    my_layer = model.get_layer(dense_type)
    my_layer.trainable = True

    for layer in my_layer.layers:
        if 'conv5' in layer.name:
            #print(layer.name)
            layer.trainable = True
        else:
            layer.trainable = False

    # Cuantas capas tiene el modelo DenseNet121
    print("Número de capas de DenseNet121: ", len(densenet.layers))

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=lr/10),
        metrics=["accuracy"]
    )

    model.summary()

    hist_fine = model.fit(
        train,
        # batch_size = batch_size,
        epochs = total_epochs,
        initial_epoch = hist.epoch[-1],
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist_fine)

    print('RESULTADOS EN TEST:')

    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])


    del model, score, hist, densenet, hist_fine

# %%
model_defrost_conv5_data_augmentation_lr(10, 10, 'densenet121')
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_20 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  tf.nn.bias_add_10 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.math.truediv_21 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense_10 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] -
# Epoch 18/20
# 253/253 [==============================] - 12s 47ms/step - loss: 0.0977 - accuracy: 0.9662 - val_loss: 0.1827 - val_accuracy: 0.9219
# Epoch 19/20
# 253/253 [==============================] - 12s 46ms/step - loss: 0.0912 - accuracy: 0.9703 - val_loss: 0.1961 - val_accuracy: 0.9202
# Epoch 20/20
# 253/253 [==============================] - 12s 47ms/step - loss: 0.0828 - accuracy: 0.9720 - val_loss: 0.2004 - val_accuracy: 0.9159
# RESULTADOS EN TEST:
# Pérdida en test: 0.20703834295272827
# Accuracy en test: 0.9192708134651184

# %%
model_defrost_conv5_data_augmentation_lr(10, 10, 'densenet169')
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_22 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  tf.nn.bias_add_11 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.math.truediv_23 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dense_11 (Dense)            (None, 1)                 1665
#
# =================================================================
# Total params: 12,644,545
# Trainable params: 1,665
# Non-trainable params: 12,642,880
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 18s 54ms/step - loss: 0.8433 - accuracy: 0.5664 - val_loss: 0.5440 - val_accuracy: 0.7138
# Epoch 2/10
# 253/253 [==============================] - 12s 49ms/step - loss: 0.5087 - accuracy: 0.7567 - val_loss: 0.4193 - val_accuracy: 0.8161
# Epoch 3/10
# 253/253 [==============================] - 12s 49ms/step - loss: 0.4181 - accuracy: 0.8118 - val_loss: 0.3846 - val_accuracy: 0.8369
# Epoch 4/10
# 253/253 [==============================] - 12s 49ms/step - loss: 0.3864 - accuracy: 0.8317 - val_loss: 0.3446 - val_accuracy: 0.8578
# Epoch 5/10
# 253/253 [==============================] - 12s 48ms/step - loss: 0.3564 - accuracy: 0.8501 - val_loss: 0.3197 - val_accuracy: 0.8682
# Epoch 6/10
# 253/253 [==============================] - 12s 48ms/step - loss: 0.3374 - accuracy: 0.8591 - val_loss: 0.3120 - val_accuracy: 0.8760
# Epoch 7/10
# 253/253 [==============================] - 12s 48ms/step - loss: 0.3252 - accuracy: 0.8645 - val_loss: 0.3140 - val_accuracy: 0.8690
# Epoch 8/10
# 253/253 [==============================] - 12s 49ms/step - loss: 0.3138 - accuracy: 0.8705 - val_loss: 0.2980 - val_accuracy: 0.8751
# Epoch 9/10
# 253/253 [==============================] - 12s 49ms/step - loss: 0.3059 - accuracy: 0.8718 - val_loss: 0.3049 - val_accuracy: 0.8656
# Epoch 10/10
# 253/253 [==============================] - 12s 49ms/step - loss: 0.3004 - accuracy: 0.8777 - val_loss: 0.2810 - val_accuracy: 0.8760
# RESULTADOS EN TEST:
# Pérdida en test: 0.30469056963920593
# Accuracy en test: 0.8693576455116272
# Número de capas de DenseNet121:  596
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_22 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  tf.nn.bias_add_11 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.math.truediv_23 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dense_11 (Dense)            (None, 1)                 1665
#
# =================================================================
# Total params: 12,644,545
# Trainable params: 5,915,265
# Non-trainable params: 6,729,280
# _________________________________________________________________
# Epoch 10/20
# 253/253 [==============================] - 28s 80ms/step - loss: 0.2409 - accuracy: 0.9027 - val_loss: 0.2111 - val_accuracy: 0.9098
# Epoch 11/20
# 253/253 [==============================] - 19s 74ms/step - loss: 0.1693 - accuracy: 0.9321 - val_loss: 0.1863 - val_accuracy: 0.9280
# Epoch 12/20
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_26 (InputLayer)       [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_24 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  tf.nn.bias_add_12 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.math.truediv_25 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  dense_12 (Dense)            (None, 1)                 1921
#
# =================================================================
# Total params: 18,323,905
# Trainable params: 6,980,481
# Non-trainable params: 11,343,424
# _________________________________________________________________
# Epoch 10/20
# 253/253 [==============================] - 31s 86ms/step - loss: 0.2351 - accuracy: 0.9068 - val_loss: 0.2146 - val_accuracy: 0.9211
# Epoch 11/20
# 253/253 [==============================] - 20s 80ms/step - loss: 0.1655 - accuracy: 0.9351 - val_loss: 0.2633 - val_accuracy: 0.8855
# Epoch 12/20
# 253/253 [==============================] - 20s 80ms/step - loss: 0.1295 - accuracy: 0.9510 - val_loss: 0.2054 - val_accuracy: 0.9289
# Epoch 13/20
# 253/253 [==============================] - 20s 80ms/step - loss: 0.1086 - accuracy: 0.9610 - val_loss: 0.1700 - val_accuracy: 0.9367
# Epoch 14/20
# 253/253 [==============================] - 20s 80ms/step - loss: 0.0902 - accuracy: 0.9689 - val_loss: 0.2141 - val_accuracy: 0.9237
# Epoch 15/20
# 253/253 [==============================] - 20s 80ms/step - loss: 0.0779 - accuracy: 0.9732 - val_loss: 0.5393 - val_accuracy: 0.8170
# Epoch 16/20
# 253/253 [==============================] - 20s 80ms/step - loss: 0.0664 - accuracy: 0.9779 - val_loss: 0.1715 - val_accuracy: 0.9402
# Epoch 17/20
# 253/253 [==============================] - 20s 80ms/step - loss: 0.0564 - accuracy: 0.9813 - val_loss: 0.2576 - val_accuracy: 0.8985
# Epoch 18/20
# 253/253 [==============================] - 20s 81ms/step - loss: 0.0469 - accuracy: 0.9870 - val_loss: 0.1748 - val_accuracy: 0.9384
# Epoch 19/20
# 253/253 [==============================] - 20s 81ms/step - loss: 0.0412 - accuracy: 0.9886 - val_loss: 0.3139 - val_accuracy: 0.8873
# Epoch 20/20
# 253/253 [==============================] - 20s 80ms/step - loss: 0.0337 - accuracy: 0.9911 - val_loss: 0.1832 - val_accuracy: 0.9436
# RESULTADOS EN TEST:
# Pérdida en test: 0.15959157049655914
# Accuracy en test: 0.9440104365348816

# %% [markdown]
# ## Fine tuning - SGD
# En este modelo, para la parte de fine-tuning, una vez descongelada el último bloque *denso*, usaremos como función de optimización la función de *Stochastic Gradient Descent* con un learning rate de 0.001 aplicando un momentum de *Nesterov* de 0.9.
#
# Se han elegido estos parámetros y esta función de optimización porque es la que se usa en el entrenamiento de DenseNet con ImageNet en las últimas épocas, según el paper oficial.

# %%
def model_defrost_conv5_lr_SGD(epochs_frozen, epochs_defrost, dense_type):

    ############################################################
    ### Transfer learning
    ############################################################        
    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False

    inputs = keras.Input(shape=(image_size,image_size,channels))
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)
    model.summary()

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train,
        epochs = epochs_frozen,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del score

    ############################################################
    ### Fine-tuning
    ############################################################

    total_epochs = epochs_frozen + epochs_defrost

    my_layer = model.get_layer(dense_type)
    my_layer.trainable = True

    for layer in my_layer.layers:
        if 'conv5' in layer.name:
            #print(layer.name)
            layer.trainable = True
        else:
            layer.trainable = False

    # Cuantas capas tiene el modelo DenseNet121
    # print("Número de capas de DenseNet121: ", len(densenet.layers))

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.SGD(learning_rate=0.001
                                            , nesterov = True
                                            , momentum = 0.9),
        metrics=["accuracy"]
    )

    model.summary()

    hist = model.fit(
        train,
        epochs = total_epochs,
        initial_epoch = hist.epoch[-1],
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')

    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])


    del model, score, hist, densenet

# %%
model_defrost_conv5_lr_SGD(10, 20, 'densenet121')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 4s 0us/step
# 29097984/29084464 [==============================] - 4s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 17s 43ms/step - loss: 0.4279 - accuracy: 0.8042 - val_loss: 0.3019 - val_accuracy: 0.8760
# Epoch 2/10
# 253/253 [==============================] - 8s 32ms/step - loss: 0.2796 - accuracy: 0.8858 - val_loss: 0.2796 - val_accuracy: 0.8682
# Epoch 3/10
# 253/253 [==============================] - 8s 31ms/step - loss: 0.2512 - accuracy: 0.9005 - val_loss: 0.3145 - val_accuracy: 0.8500
# Epoch 4/10
# 253/253 [==============================] - 8s 33ms/step - loss: 0.2338 - accuracy: 0.9069 - val_loss: 0.2703 - val_accuracy: 0.8734
# Epoch 5/10
# 253/253 [==============================] - 8s 33ms/step - loss: 0.2229 - accuracy: 0.9096 - val_loss: 0.2558 - val_accuracy: 0.8777
# Epoch 6/10
# 253/253 [==============================] - 8s 33ms/step - loss: 0.2126 - accuracy: 0.9177 - val_loss: 0.2675 - val_accuracy: 0.8768
# Epoch 7/10
# 253/253 [==============================] - 8s 32ms/step - loss: 0.2058 - accuracy: 0.9197 - val_loss: 0.2263 - val_accuracy: 0.8994
# Epoch 8/10
# 253/253 [==============================] - 8s 32ms/step - loss: 0.2000 - accuracy: 0.9199 - val_loss: 0.2217 - val_accuracy: 0.9046
# Epoch 9/10
# 253/253 [==============================] - 8s 31ms/step - loss: 0.1953 - accuracy: 0.9234 - val_loss: 0.2153 - val_accuracy: 0.9089
# Epoch 10/10
# 253/253 [==============================] - 8s 31ms/step - loss: 0.1912 - accuracy: 0.9230 - val_loss: 0.2092 - val_accuracy: 0.9115
# RESULTADOS EN TEST:
# Pérdida en test: 0.23025411367416382
# Accuracy en test: 0.9084201455116272
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params:
ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.2498 - val_accuracy: 0.9297
# Epoch 25/30
# 253/253 [==============================] - 20s 78ms/step - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.2252 - val_accuracy: 0.9376
# Epoch 26/30
# 253/253 [==============================] - 20s 78ms/step - loss: 0.0066 - accuracy: 0.9990 - val_loss: 0.2043 - val_accuracy: 0.9488
# Epoch 27/30
# 253/253 [==============================] - 19s 77ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.2486 - val_accuracy: 0.9384
# Epoch 28/30
# 253/253 [==============================] - 19s 76ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.2663 - val_accuracy: 0.9384
# Epoch 29/30
# 253/253 [==============================] - 20s 77ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9488
# Epoch 30/30
# 253/253 [==============================] - 20s 78ms/step - loss: 8.7246e-04 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9497
# RESULTADOS EN TEST:
# Pérdida en test: 0.22042196989059448
# Accuracy en test: 0.9513888955116272

# %% [markdown]
# Usaremos *checkpoints* ya que aparecen picos en la validación y nos interesa quedarnos con el mejor resultado.

# %%
def model_defrost_conv5_data_augmentation_lr_SGD(epochs_frozen, epochs_defrost, dense_type):

    ############################################################
    ### Transfer learning
    ############################################################

    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
    ])

    # map aplica la función pasada como primer argumento a todos los elemetos
    # del dataset y devuelve un nuevo dataset que contiene los elementos
    # transformados
    train_aug = train.map(lambda x, y: (data_augmentation(x, training=True), y))
    
    # for image, _ in train.take(1):
    #     plt.figure(figsize=(10, 10))
    #     first_image = image[0]
    #     for i in range(9):
    #         ax = plt.subplot(3, 3, i + 1)
    #         augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    #         plt.imshow(augmented_image[0] / 255)
    #         plt.axis('off')
        
    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False

    inputs = keras.Input(shape=(image_size,image_size,channels))
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)
    model.summary()

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = epochs_frozen,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del score

    ############################################################
    ### Fine-tuning
    ############################################################

    total_epochs = epochs_frozen + epochs_defrost
    
    checkpoint_filepath = '/tmp/checkpoint'
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='accuracy',
        mode='max',
        save_best_only=True
    )

    my_layer = model.get_layer(dense_type)
    my_layer.trainable = True

    for layer in my_layer.layers:
        if 'conv5' in layer.name:
            #print(layer.name)
            layer.trainable = True
        else:
            layer.trainable = False

    # Cuantas capas tiene el modelo DenseNet121
    # print("Número de capas de DenseNet121: ", len(densenet.layers))

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.SGD(
            learning_rate=0.001,
            nesterov = True,
            momentum = 0.9
        ),
        metrics=["accuracy"]
    )

    model.summary()

    hist_fine = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = total_epochs,
        callbacks=[model_checkpoint_callback],
        initial_epoch = hist.epoch[-1],
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist_fine)

    print('RESULTADOS EN TEST:')

    model.load_weights(checkpoint_filepath)
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])


    del model, score, hist, densenet, hist_fine

# %%
model_defrost_conv5_data_augmentation_lr_SGD(10, 25, 'densenet121')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_3 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 35s 105ms/step - loss: 0.4685 - accuracy: 0.7899 - val_loss: 0.3324 - val_accuracy: 0.8621
# Epoch 2/10
# 253/253 [==============================] - 24s 93ms/step - loss: 0.3133 - accuracy: 0.8689 - val_loss: 0.2839 - val_accuracy: 0.8820
# Epoch 3/10
# 253/253 [==============================] - 22s 88ms/step - loss: 0.2748 - accuracy: 0.8873 - val_loss: 0.2933 - val_accuracy: 0.8742
# Epoch 4/10
# 253/253 [==============================] - 23s 89ms/step - loss: 0.2601 - accuracy: 0.8924 - val_loss: 0.3006 - val_accuracy: 0.8621
# Epoch 5/10
# 253/253 [==============================] - 22s 88ms/step - loss: 0.2460 - accuracy: 0.9028 - val_loss: 0.2602 - val_accuracy: 0.8968
# Epoch 6/10
# 253/253 [==============================] - 22s 88ms/step - loss: 0.2466 - accuracy: 0.9001 - val_loss: 0.3049 - val_accuracy: 0.8621
# Epoch 7/10
# 253/253 [==============================] - 22s 88ms/step - loss: 0.2459 - accuracy: 0.9000 - val_loss: 0.2680 - val_accuracy: 0.8864
# Epoch 8/10
# 253/253 [==============================] - 22s 87ms/step - loss: 0.2468 - accuracy: 0.9003 - val_loss: 0.2344 - val_accuracy: 0.8994
# Epoch 9/10
# 253/253 [==============================] - 22s 88ms/step - loss: 0.2334 - accuracy: 0.9062 - val_loss: 0.2294 - val_accuracy: 0.9072
# Epoch 10/10
# 253/253 [==============================] - 23s 89ms/step - loss: 0.2357 - accuracy: 0.9069 - val_loss: 0.2707 - val_accuracy: 0.8794
# RESULTADOS EN TEST:
# Pérdida en test: 0.28300851583480835
# Accuracy en test: 0.8815104365348816
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_3 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 2,159,105
# Non-trainable params: 4,879,424
# _________________________________________________________________
# Epoch 10/35
# 253/253 [==============================] - 37s 114ms/step - loss: 0.2722 - accuracy: 0.8924 - val_loss: 0.2176 - val_accuracy: 0.9193
# Epoch 11/35
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2096 - accuracy: 0.9147 - val_loss: 0.2030 - val_accuracy: 0.9063
# Epoch 12/35
# 253/253 [==============================] - 27s 106ms/step - loss: 0.1844 - accuracy: 0.9256 - val_loss: 0.1995 - val_accuracy: 0.9211
# Epoch 13/35
# 253/253 [==============================] - 27s 105ms/step - loss: 0.1726 - accuracy: 0.9312 - val_loss: 0.3016 - val_accuracy: 0.8708
# Epoch 14/35
# 253/253 [==============================] - 27s 106ms/step - loss: 0.1665 - accuracy: 0.9328 - val_loss: 0.5183 - val_accuracy: 0.7944
# 253/253 [==============================] - 36s 140ms/step - loss: 0.0671 - accuracy: 0.9747 - val_loss: 0.1653 - val_accuracy: 0.9402
# Epoch 35/35
# 253/253 [==============================] - 36s 141ms/step - loss: 0.0669 - accuracy: 0.9752 - val_loss: 0.1670 - val_accuracy: 0.9384
# RESULTADOS EN TEST:
# Pérdida en test: 0.17393365502357483
# Accuracy en test: 0.9483506679534912

# %%
# Con 25 épocas es suficiente para alcanzar la mayor precisión.
model_defrost_conv5_data_augmentation_lr_SGD(10, 50, 'densenet201')
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_14 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  tf.nn.bias_add_7 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_15 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  dense_7 (Dense)             (None, 1)                 1921
#
# =================================================================
# Total params: 18,323,905
# Trainable params: 1,921
# Non-trainable params: 18,321,984
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 23s 72ms/step - loss: 0.4274 - accuracy: 0.8068 - val_loss: 0.3199 - val_accuracy: 0.8682
# Epoch 2/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2986 - accuracy: 0.8759 - val_loss: 0.2787 - val_accuracy: 0.8846
# Epoch 3/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2728 - accuracy: 0.8889 - val_loss: 0.2597 - val_accuracy: 0.8951
# Epoch 4/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2637 - accuracy: 0.8917 - val_loss: 0.2892 - val_accuracy: 0.8777
# Epoch 5/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2493 - accuracy: 0.8966 - val_loss: 0.2764 - val_accuracy: 0.8838
# Epoch 6/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2400 - accuracy: 0.9038 - val_loss: 0.2320 - val_accuracy: 0.9098
# Epoch 7/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2435 - accuracy: 0.8999 - val_loss: 0.2481 - val_accuracy: 0.8985
# Epoch 8/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2416 - accuracy: 0.8997 - val_loss: 0.2257 - val_accuracy: 0.9133
# Epoch 9/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2387 - accuracy: 0.9007 - val_loss: 0.2192 - val_accuracy: 0.9150
# Epoch 10/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2265 - accuracy: 0.9140 - val_loss: 0.2336 - val_accuracy: 0.9063
# RESULTADOS EN TEST:
# Pérdida en test: 0.23248052597045898
# Accuracy en test: 0.9071180820465088
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_14 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  tf.nn.bias_add_7 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_15 (TFOpLam  (None, 75, 75, 3)        0
#  bda)
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  dense_7 (Dense)             (None, 1)                 1921
#
# =================================================================
# Total params: 18,323,905
# Trainable params: 6,980,481
# Non-trainable params: 11,343,424
# _________________________________________________________________
# Epoch 10/60
# 253/253 [==============================] - 32s 101ms/step - loss: 0.3263 - accuracy: 0.8731 - val_loss: 0.2069 - val_accuracy: 0.9219
# Epoch 11/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0.2059 - accuracy: 0.9120 - val_loss: 0.4590 - val_accuracy: 0.7936
# Epoch 12/60
# 253/253 [==============================] - 24s 94ms/step - loss: 0.1872 - accuracy: 0.9224 - val_loss: 0.1657 - val_accuracy: 0.9436
# Epoch 13/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0.1666 - accuracy: 0.9347 - val_loss: 0.3251 - val_accuracy: 0.8569
# Epoch 14/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0.1557 - accuracy: 0.9364 - val_loss: 0.4575 - val_accuracy: 0.8161
# Epoch 15/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0.1481 - accuracy: 0.9411 - val_loss: 0.2567 - val_accuracy: 0.8951
# Epoch 16/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0.1431 - accuracy: 0.9461 - val_loss: 0.2023 - val_accuracy: 0.9124
# Epoch 17/60
# 253/253 [==============================] - 24s 94ms/step - loss: 0.1335 - accuracy: 0.9477 - val_loss: 0.1411 - val_accuracy: 0.9514
# Epoch 18/60
# 253/253 [==============================] - 24s 94ms/step - loss: 0.1271 - accuracy: 0.9484 - val_loss: 0.1612 - val_accuracy: 0.9445
# Epoch 19/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0550 - accuracy: 0.9798 - val_loss: 0.1516 - val_accuracy: 0.9506
# Epoch 43/60
# 253/253 [==============================] - 24s 93ms/step - loss: 0.0509 - accuracy: 0.9809 - val_loss: 0.1797 - val_accuracy: 0.9315
# Epoch 44/60
# 253/253 [==============================] - 24s 94ms/step - loss: 0.0463 - accuracy: 0.9823 - val_loss: 0.1879 - val_accuracy: 0.9376
# Epoch 45/60
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0527 - accuracy: 0.9795 - val_loss: 0.1657 - val_accuracy: 0.9445
# Epoch 46/60
# 253/253 [==============================] - 23s 93ms/step - loss: 0.0486 - accuracy: 0.9825 - val_loss: 0.1472 - val_accuracy: 0.9540
# Epoch 47/60
# 253/253 [==============================] - 24s 96ms/step - loss: 0.0420 - accuracy: 0.9835 - val_loss: 0.1599 - val_accuracy: 0.9471
# Epoch 48/60
# 253/253 [==============================] - 23s 93ms/step - loss: 0.0418 - accuracy: 0.9834 - val_loss: 0.1579 - val_accuracy: 0.9480
# Epoch 49/60
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0434 - accuracy: 0.9830 - val_loss: 0.1846 - val_accuracy: 0.9341
# Epoch 50/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0.0397 - accuracy: 0.9853 - val_loss: 0.1694 - val_accuracy: 0.9462
# Epoch 51/60
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0407 - accuracy: 0.9851 - val_loss: 0.1352 - val_accuracy: 0.9488
# Epoch 52/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0.0339 - accuracy: 0.9890 - val_loss: 0.1413 - val_accuracy: 0.9558
# Epoch 53/60
# 253/253 [==============================] - 24s 93ms/step - loss: 0.0365 - accuracy: 0.9864 - val_loss: 0.1905 - val_accuracy: 0.9462
# Epoch 54/60
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0374 - accuracy: 0.9857 - val_loss: 0.1332 - val_accuracy: 0.9549
# Epoch 55/60
# 253/253 [==============================] - 24s 95ms/step - loss: 0.0303 - accuracy: 0.9905 - val_loss: 0.1431 - val_accuracy: 0.9584
# Epoch 56/60
# 253/253 [==============================] - 23s 93ms/step - loss: 0.0288 - accuracy: 0.9876 - val_loss: 0.1602 - val_accuracy: 0.9549
# Epoch 57/60
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0309 - accuracy: 0.9891 - val_loss: 0.1812 - val_accuracy: 0.9454
# Epoch 58/60
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0366 - accuracy: 0.9860 - val_loss: 0.2405 - val_accuracy: 0.9315
# Epoch 59/60
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0302 - accuracy: 0.9881 - val_loss: 0.1671 - val_accuracy: 0.9532
# Epoch 60/60
# 253/253 [==============================] - 23s 92ms/step - loss: 0.0297 - accuracy: 0.9888 - val_loss: 0.1565 - val_accuracy: 0.9592
# RESULTADOS EN TEST:
# Pérdida en test: 0.13120751082897186
# Accuracy en test: 0.9613715410232544

# %%
def model_defrost_conv5_data_augmentation_lr_SGD_II(epochs_frozen, epochs_defrost, dense_type):

    ############################################################
    ### Transfer learning
    ############################################################

    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
    ])

    # map aplica la función pasada como primer argumento a todos los elemetos
    # del dataset y devuelve un nuevo dataset que contiene los elementos
    # transformados
    train_aug = train.map(lambda x, y: (data_augmentation(x, training=True), y))
        
    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False

    inputs = keras.Input(shape=(image_size,image_size,channels))
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)
    model.summary()

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = epochs_frozen,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del score

    ############################################################
    ### Fine-tuning
    ############################################################

    total_epochs = epochs_frozen + epochs_defrost
    
    checkpoint_filepath = '/tmp/checkpoint'
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='accuracy',
        mode='max',
        save_best_only=True
    )

    my_layer = model.get_layer(dense_type)
    my_layer.trainable = True

    for layer in my_layer.layers:
        if ('conv4' in layer.name) or ('conv5' in layer.name) :
            #print(layer.name)
            layer.trainable = True
        else:
            layer.trainable = False

    # Cuantas capas tiene el modelo DenseNet121
    # print("Número de capas de DenseNet121: ", len(densenet.layers))

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, nesterov = True, momentum = 0.9),
        metrics=["accuracy"]
    )

    model.summary()

    hist_fine = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = total_epochs,
        callbacks=[model_checkpoint_callback],
        initial_epoch = hist.epoch[-1],
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist_fine)

    print('RESULTADOS EN TEST:')

    model.load_weights(checkpoint_filepath)
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])


    del model, score, hist, densenet, hist_fine

# %%
model_defrost_conv5_data_augmentation_lr_SGD_II(10, 35, 'densenet121')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 46s 118ms/step - loss: 0.4649 - accuracy: 0.7931 - val_loss: 0.3049 - val_accuracy: 0.8786
# Epoch 2/10
# 253/253 [==============================] - 23s 92ms/step - loss: 0.3115 - accuracy: 0.8710 - val_loss: 0.3186 - val_accuracy: 0.8560
# Epoch 3/10
# 253/253 [==============================] - 24s 93ms/step - loss: 0.2821 - accuracy: 0.8841 - val_loss: 0.4009 - val_accuracy: 0.8092
# Epoch 4/10
# 253/253 [==============================] - 23s 92ms/step - loss: 0.2655 - accuracy: 0.8886 - val_loss: 0.2865 - val_accuracy: 0.8760
# Epoch 5/10
# 253/253 [==============================] - 23s 91ms/step - loss: 0.2521 - accuracy: 0.9022 - val_loss: 0.2400 - val_accuracy: 0.8985
# Epoch 6/10
# 253/253 [==============================] - 23s 90ms/step - loss: 0.2479 - accuracy: 0.8961 - val_loss: 0.3150 - val_accuracy: 0.8621
# Epoch 7/10
# 253/253 [==============================] - 23s 91ms/step - loss: 0.2461 - accuracy: 0.9000 - val_loss: 0.2321 - val_accuracy: 0.9046
# Epoch 8/10
# 253/253 [==============================] - 23s 91ms/step - loss: 0.2450 - accuracy: 0.8991 - val_loss: 0.2339 - val_accuracy: 0.9003
# Epoch 9/10
# 253/253 [==============================] - 23s 91ms/step - loss: 0.2336 - accuracy: 0.9077 - val_loss: 0.2362 - val_accuracy: 0.9003
# Epoch 10/10
# 253/253 [==============================] - 23s 91ms/step - loss: 0.2311 - accuracy: 0.9087 - val_loss: 0.2154 - val_accuracy: 0.9107
# RESULTADOS EN TEST:
# Pérdida en test: 0.24341543018817902
# Accuracy en test: 0.9032118320465088
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 4,996,865
# Non-trainable params: 2,041,664
# _________________________________________________________________
# Epoch 10/45
# 253/253 [==============================] - 48s 145ms/step - loss: 0.2896 - accuracy: 0.8837 - val_loss: 2.0104 - val_accuracy: 0.6062
# Epoch 11/45
# 253/253 [==============================] - 34s 133ms/step - loss: 0
# 253/253 [==============================] - 53s 209ms/step - loss: 0.0322 - accuracy: 0.9887 - val_loss: 0.0863 - val_accuracy: 0.9679
# Epoch 36/45
# 253/253 [==============================] - 54s 214ms/step - loss: 0.0267 - accuracy: 0.9897 - val_loss: 0.3293 - val_accuracy: 0.9029
# Epoch 37/45
# 253/253 [==============================] - 53s 209ms/step - loss: 0.0344 - accuracy: 0.9861 - val_loss: 0.0956 - val_accuracy: 0.9670
# Epoch 38/45
# 253/253 [==============================] - 55s 216ms/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 0.1785 - val_accuracy: 0.9601
# Epoch 39/45
# 253/253 [==============================] - 53s 209ms/step - loss: 0.0276 - accuracy: 0.9908 - val_loss: 0.1197 - val_accuracy: 0.9644
# Epoch 40/45
# 253/253 [==============================] - 54s 214ms/step - loss: 0.0236 - accuracy: 0.9922 - val_loss: 0.0882 - val_accuracy: 0.9688
# Epoch 41/45
# 253/253 [==============================] - 53s 209ms/step - loss: 0.0276 - accuracy: 0.9887 - val_loss: 0.1042 - val_accuracy: 0.9575
# Epoch 42/45
# 253/253 [==============================] - 55s 218ms/step - loss: 0.0188 - accuracy: 0.9936 - val_loss: 0.1964 - val_accuracy: 0.9497
# Epoch 43/45
# 253/253 [==============================] - 54s 213ms/step - loss: 0.0178 - accuracy: 0.9931 - val_loss: 0.0997 - val_accuracy: 0.9722
# Epoch 44/45
# 253/253 [==============================] - 54s 215ms/step - loss: 0.0194 - accuracy: 0.9923 - val_loss: 0.1296 - val_accuracy: 0.9627
# Epoch 45/45
# 253/253 [==============================] - 54s 214ms/step - loss: 0.0218 - accuracy: 0.9910 - val_loss: 0.1153 - val_accuracy: 0.9679
# RESULTADOS EN TEST:
# Pérdida en test: 0.18050745129585266
# Accuracy en test: 0.9518229365348816

# %%
def model_defrost_conv5_data_augmentation_lr_SGD_III(epochs_frozen, epochs_defrost, dense_type):

    ############################################################
    ### Transfer learning
    ############################################################

    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
    ])

    # map aplica la función pasada como primer argumento a todos los elemetos
    # del dataset y devuelve un nuevo dataset que contiene los elementos
    # transformados
    train_aug = train.map(lambda x, y: (data_augmentation(x, training=True), y))
        
    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False

    inputs = keras.Input(shape=(image_size,image_size,channels))
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)
    model.summary()

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = epochs_frozen,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del score

    ############################################################
    ### Fine-tuning
    ############################################################

    total_epochs = epochs_frozen + epochs_defrost
    
    checkpoint_filepath = '/tmp/checkpoint'
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='accuracy',
        mode='max',
        save_best_only=True
    )

    my_layer = model.get_layer(dense_type)
    my_layer.trainable = True

    for layer in my_layer.layers:
        if ('conv4' in layer.name) or ('conv5' in layer.name) or ('conv3' in layer.name):
            #print(layer.name)
            layer.trainable = True
        else:
            layer.trainable = False

    # Cuantas capas tiene el modelo DenseNet121
    # print("Número de capas de DenseNet121: ", len(densenet.layers))

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, nesterov = True, momentum = 0.9),
        metrics=["accuracy"]
    )

    model.summary()

    hist_fine = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = total_epochs,
        callbacks=[model_checkpoint_callback],
        initial_epoch = hist.epoch[-1],
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist_fine)

    print('RESULTADOS EN TEST:')

    model.load_weights(checkpoint_filepath)
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])


    del model, score, hist, densenet, hist_fine

# %%
model_defrost_conv5_data_augmentation_lr_SGD_III(10, 35, 'densenet121')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 5s 0us/step
# 29097984/29084464 [==============================] - 5s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 21s 59ms/step - loss: 0.4588 - accuracy: 0.7909 - val_loss: 0.3095 - val_accuracy: 0.8742
# Epoch 2/10
# 253/253 [==============================] - 12s 48ms/step - loss: 0.3143 - accuracy: 0.8660 - val_loss: 0.3151 - val_accuracy: 0.8647
# Epoch 3/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.2832 - accuracy: 0.8849 - val_loss: 0.3815 - val_accuracy: 0.8205
# Epoch 4/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.2668 - accuracy: 0.8891 - val_loss: 0.2635 - val_accuracy: 0.8838
# Epoch 5/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.2524 - accuracy: 0.8985 - val_loss: 0.2406 - val_accuracy: 0.8933
# Epoch 6/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.2491 - accuracy: 0.9007 - val_loss: 0.3534 - val_accuracy: 0.8404
# Epoch 7/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.2451 - accuracy: 0.9039 - val_loss: 0.2504 - val_accuracy: 0.8881
# Epoch 8/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.2520 - accuracy: 0.8987 - val_loss: 0.2344 - val_accuracy: 0.8959
# Epoch 9/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.2322 - accuracy: 0.9073 - val_loss: 0.2238 - val_accuracy: 0.9003
# Epoch 10/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.2358 - accuracy: 0.9032 - val_loss: 0.2278 - val_accuracy: 0.8985
# RESULTADOS EN TEST:
# Pérdida en test: 0.2472260296344757
# Accuracy en test: 0.8997395634651184
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 5,916,545
# Non-trainable params: 1,121,984
# _________________________________________________________________
# Epoch 10/45
# 253/253 [==============================] - 32s 102ms/step - loss: 0.2864 - accuracy: 0.8930 - val_loss: 1.8374 - val_accuracy: 0.5846
# Epoch 11/45
# 253/253 [==============================] - 24s 95ms/step - loss: 0.1652 - accuracy: 0.9378 - val_loss: 0.1259 - val_accuracy: 0.9497
# Epoch 12/45
# 253/253 [==============================] - 24s 97ms/step - loss: 0.1169 - accuracy: 0.9539 - val_loss: 0.1326 - val_accuracy: 0.9393
# Epoch 13/45
# 253/253 [==============================] - 24s 95ms/step - loss: 0.0980 - accuracy: 0.9624 - val_loss: 0.1323 - val_accuracy: 0.9480
# Epoch 14/45
# 253/253 [==============================] - 24s 94ms/step - loss: 0.0914 - accuracy: 0.9649 - val_loss: 0.1176 - val_accuracy: 0.9592
# Epoch 15/45
# 253/253 [==============================] - 24s 96ms/step - loss: 0.0842 - accuracy: 0.9700 - val_loss: 0.1181 - val_accuracy: 0.9523
# Epoch 16/45
# 253/253 [==============================] - 24s 96ms/step - loss: 0.0796 - accuracy: 0.9709 - val_loss: 0.1084 - val_accuracy: 0.9575
# Epoch 17/45
# 253/253 [==============================] - 24s 95ms/step - loss: 0.
45
# 253/253 [==============================] - 24s 95ms/step - loss: 0.0208 - accuracy: 0.9926 - val_loss: 0.1375 - val_accuracy: 0.9670
# Epoch 44/45
# 253/253 [==============================] - 24s 95ms/step - loss: 0.0168 - accuracy: 0.9942 - val_loss: 0.1261 - val_accuracy: 0.9618
# Epoch 45/45
# 253/253 [==============================] - 24s 95ms/step - loss: 0.0177 - accuracy: 0.9928 - val_loss: 0.1087 - val_accuracy: 0.9705
# RESULTADOS EN TEST:
# Pérdida en test: 0.13080452382564545
# Accuracy en test: 0.9661458134651184

# %%
model_defrost_conv5_data_augmentation_lr_SGD_III(10, 35, 'densenet169')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step
# 51888128/51877672 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dense (Dense)               (None, 1)                 1665
#
# =================================================================
# Total params: 12,644,545
# Trainable params: 1,665
# Non-trainable params: 12,642,880
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 52s 130ms/step - loss: 0.4054 - accuracy: 0.8244 - val_loss: 0.3062 - val_accuracy: 0.8838
# Epoch 2/10
# 253/253 [==============================] - 27s 108ms/step - loss: 0.2860 - accuracy: 0.8820 - val_loss: 0.3235 - val_accuracy: 0.8604
# Epoch 3/10
# 253/253 [==============================] - 27s 108ms/step - loss: 0.2746 - accuracy: 0.8844 - val_loss: 0.3382 - val_accuracy: 0.8439
# Epoch 4/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2515 - accuracy: 0.8981 - val_loss: 0.3362 - val_accuracy: 0.8465
# Epoch 5/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2521 - accuracy: 0.8990 - val_loss: 0.2384 - val_accuracy: 0.9081
# Epoch 6/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2447 - accuracy: 0.8994 - val_loss: 0.2647 - val_accuracy: 0.8777
# Epoch 7/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2387 - accuracy: 0.9003 - val_loss: 0.2538 - val_accuracy: 0.8916
# Epoch 8/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2336 - accuracy: 0.9053 - val_loss: 0.2299 - val_accuracy: 0.9063
# Epoch 9/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2310 - accuracy: 0.9075 - val_loss: 0.2386 - val_accuracy: 0.8942
# Epoch 10/10
# 253/253 [==============================] - 28s 109ms/step - loss: 0.2266 - accuracy: 0.9080 - val_loss: 0.2204 - val_accuracy: 0.9176
# RESULTADOS EN TEST:
# Pérdida en test: 0.23183761537075043
# Accuracy en test: 0.9066840410232544
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dense (Dense)               (None, 1)                 1665
#
# =================================================================
# Total params: 12,644,545
# Trainable params: 11,151,105
# Non-trainable params: 1,493,440
# _________________________________________________________________
# Epoch 10/45
# 253/253 [==============================] - 75s 223ms/step - loss: 0.3308 - accuracy: 0.8682 - val_loss: 2.3509 - val_accuracy: 0.5733
# Epoch 11/45
# 253/253 [==============================] - 52s 204ms/step - loss: 0.1820 - accuracy: 0.9329 - val_loss: 0.1746 - val_accuracy: 0.9289
# Epoch 12/45
# 253/253 [==============================] - 52s 205ms/step - loss: 0.1203 - accuracy: 0.9560 - val_loss: 0.1423 - val_accuracy: 0.9376
# Epoch 13/45
# 253/253 [==============================] - 52s 203ms/step - loss: 0.0968 - accuracy: 0.9643 - val_loss: 0.2248 - val_accuracy: 0.9150
# Epoch 14/45
# 253/253 [==============================] - 51s 203ms/step - loss: 0.0956 - accuracy: 0.9654 - val_loss: 0.1353 - val_accuracy: 0.9532
# Epoch 45/45
# 253/253 [==============================] - 60s 237ms/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 0.1281 - val_accuracy: 0.9653
# RESULTADOS EN TEST:
# Pérdida en test: 0.11069173365831375
# Accuracy en test: 0.9743923544883728

# %%
def model_defrost_conv5_data_augmentation_lr_SGD_IIII(epochs_frozen, epochs_defrost, dense_type):

    ############################################################
    ### Transfer learning
    ############################################################

    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
    ])

    # map aplica la función pasada como primer argumento a todos los elemetos
    # del dataset y devuelve un nuevo dataset que contiene los elementos
    # transformados
    train_aug = train.map(lambda x, y: (data_augmentation(x, training=True), y))
        
    densenet = cargaDenseNet(dense_type)

    densenet.trainable = False

    inputs = keras.Input(shape=(image_size,image_size,channels))
    x = preprocess_input(inputs)
    x = densenet(x, training = False)
    outputs = Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)
    model.summary()

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )

    hist = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = epochs_frozen,
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist)

    print('RESULTADOS EN TEST:')
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])

    del score

    ############################################################
    ### Fine-tuning
    ############################################################

    total_epochs = epochs_frozen + epochs_defrost
    
    checkpoint_filepath = '/tmp/checkpoint'
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='accuracy',
        mode='max',
        save_best_only=True
    )

    my_layer = model.get_layer(dense_type)
    my_layer.trainable = True

    for layer in my_layer.layers:
        if ('conv4' in layer.name) or ('conv5' in layer.name) or ('conv3' in layer.name) or ('conv2' in layer.name):
            #print(layer.name)
            layer.trainable = True
        else:
            layer.trainable = False

    # Cuantas capas tiene el modelo DenseNet121
    # print("Número de capas de DenseNet121: ", len(densenet.layers))

    model.compile(
        loss = "binary_crossentropy",
        optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, nesterov = True, momentum = 0.9),
        metrics=["accuracy"]
    )

    model.summary()

    hist_fine = model.fit(
        train_aug,
        # batch_size = batch_size,
        epochs = total_epochs,
        callbacks=[model_checkpoint_callback],
        initial_epoch = hist.epoch[-1],
        validation_data = validation,
        verbose = 1
    )

    mostrarEvolucion(hist_fine)

    print('RESULTADOS EN TEST:')

    model.load_weights(checkpoint_filepath)
    score = model.evaluate(test, verbose=0)
    print('Pérdida en test:', score[0])
    print('Accuracy en test:', score[1])
    
    model.save(dense_type + 'IIII.h5')


    del model, score, hist, densenet, hist_fine

# %%
model_defrost_conv5_data_augmentation_lr_SGD_IIII(10, 25, 'densenet121')
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_6 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.nn.bias_add_3 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_7 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 16s 50ms/step - loss: 0.5022 - accuracy: 0.7747 - val_loss: 0.4004 - val_accuracy: 0.8265
# Epoch 2/10
# 253/253 [==============================] - 12s 46ms/step - loss: 0.3270 - accuracy: 0.8647 - val_loss: 0.2737 - val_accuracy: 0.8838
# Epoch 3/10
# 253/253 [==============================] - 12s 46ms/step - loss: 0.2857 - accuracy: 0.8800 - val_loss: 0.2799 - val_accuracy: 0.8794
# Epoch 4/10
# 253/253 [==============================] - 12s 46ms/step - loss: 0.2755 - accuracy: 0.8824 - val_loss: 0.2509 - val_accuracy: 0.8899
# Epoch 5/10
# 253/253 [==============================] - 12s 47ms/step - loss: 0.
# Epoch 4/10
# 253/253 [==============================] - 14s 57ms/step - loss: 0.2579 - accuracy: 0.8961 - val_loss: 0.3013 - val_accuracy: 0.8595
# Epoch 5/10
# 253/253 [==============================] - 14s 57ms/step - loss: 0.2527 - accuracy: 0.8946 - val_loss: 0.2443 - val_accuracy: 0.8959
# Epoch 6/10
# 253/253 [==============================] - 14s 57ms/step - loss: 0.2448 - accuracy: 0.8999 - val_loss: 0.2730 - val_accuracy: 0.8682
# Epoch 7/10
# 253/253 [==============================] - 15s 57ms/step - loss: 0.2374 - accuracy: 0.8984 - val_loss: 0.2585 - val_accuracy: 0.8838
# Epoch 8/10
# 253/253 [==============================] - 15s 57ms/step - loss: 0.2328 - accuracy: 0.9049 - val_loss: 0.2196 - val_accuracy: 0.9124
# Epoch 9/10
# 253/253 [==============================] - 14s 57ms/step - loss: 0.2309 - accuracy: 0.9110 - val_loss: 0.2332 - val_accuracy: 0.9072
# Epoch 10/10
# 253/253 [==============================] - 14s 56ms/step - loss: 0.2272 - accuracy: 0.9095 - val_loss: 0.2180 - val_accuracy: 0.9098
# RESULTADOS EN TEST:
# Pérdida en test: 0.2255127727985382
# Accuracy en test: 0.9140625
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv (TFOpLambda  (None, 75, 75, 3)        0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 75, 75, 3)        0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dense (Dense)               (None, 1)                 1665
#
# =================================================================
# Total params: 12,644,545
# Trainable params: 11,486,145
# Non-trainable params: 1,158,400
# _________________________________________________________________
# Epoch 10/45
# 253/253 [==============================] - 48s 151ms/step - loss: 0.3826 - accuracy: 0.8318 - val_loss: 2.1339 - val_accuracy: 0.5733
# Epoch 11/45
# 253/253 [==============================] - 35s 138ms/step - loss: 0.1825 - accuracy: 0.9369 - val_loss: 0.1486 - val_accuracy: 0.9393
# Epoch 12/45
# 253/253 [==============================] - 35s 138ms/step - loss: 0.1335 - accuracy: 0.9500 - val_loss: 0.1362 - val_accuracy: 0.9488
# Epoch 13/45
# 253/253 [==============================] - 35s 138ms/step - loss: 0.1098 - accuracy: 0.9593 - val_loss: 0.3420 - val_accuracy: 0.8656
# Epoch 14/45
# 253/253 [==============================] - 35s 138ms/step - loss: 0.1029 - accuracy: 0.9612 - val_loss: 0.1143 - val_accuracy: 0.9575
# Epoch 15/45
# 253/253 [==============================] - 35s 138ms/step - loss: 0.0939 - accuracy: 0.9653 - val_loss: 0.1348 - val_accuracy: 0.9471
# Epoch 16/45
# 253/253 [==============================] - 35s 138ms/step - loss: 0.0816 - accuracy: 0.9675 - val_loss: 0.1341 - val_accuracy: 0.9480
# Epoch 17/45
# 253/253 [==============================] - 35s 137ms/step - loss: 0.0834 - accuracy: 0.9693 - val_loss: 0.1155 - val_accuracy: 0.9636
# Epoch 18/45
# 253/253 [==============================] - 35s 138ms/step - loss: 0.0738 - accuracy: 0.9727 - val_loss: 0.1159 - val_accuracy: 0.9636
# Epoch 19/45
# 253/253 [==============================] - 35s 137ms/step - loss: 0.0701 - accuracy: 0.9740 - val_loss: 0.2358 - val_accuracy: 0.9089
# Epoch 20/45
# 253/253 [==============================] - 34s 136ms/step - loss: 0.0734 - accuracy: 0.9716 - val_loss: 0.1192 - val_accuracy: 0.9610
# Epoch 21/45
# 253/253 [==============================] - 35s 137ms/step - loss: 0.
45
# 253/253 [==============================] - 35s 137ms/step - loss: 0.0256 - accuracy: 0.9902 - val_loss: 0.1099 - val_accuracy: 0.9679
# Epoch 44/45
# 253/253 [==============================] - 35s 137ms/step - loss: 0.0239 - accuracy: 0.9903 - val_loss: 0.1131 - val_accuracy: 0.9688
# Epoch 45/45
# 253/253 [==============================] - 35s 140ms/step - loss: 0.0208 - accuracy: 0.9936 - val_loss: 0.1311 - val_accuracy: 0.9636
# RESULTADOS EN TEST:
# Pérdida en test: 0.1135651022195816
# Accuracy en test: 0.96875

# %%
model_defrost_conv5_data_augmentation_lr_SGD_IIII(10, 35, 'densenet201')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 15s 0us/step
# 74850304/74836368 [==============================] - 15s 0us/step
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_3 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  dense_1 (Dense)             (None, 1)                 1921
#
# =================================================================
# Total params: 18,323,905
# Trainable params: 1,921
# Non-trainable params: 18,321,984
# _________________________________________________________________
# Epoch 1/10
# 253/253 [==============================] - 26s 75ms/step - loss: 0.4236 - accuracy: 0.8053 - val_loss: 0.3138 - val_accuracy: 0.8716
# Epoch 2/10
# 253/253 [==============================] - 17s 65ms/step - loss: 0.2923 - accuracy: 0.8782 - val_loss: 0.2783 - val_accuracy: 0.8933
# Epoch 3/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2755 - accuracy: 0.8867 - val_loss: 0.3173 - val_accuracy: 0.8586
# Epoch 4/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2644 - accuracy: 0.8943 - val_loss: 0.3431 - val_accuracy: 0.8491
# Epoch 5/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2508 - accuracy: 0.8987 - val_loss: 0.2442 - val_accuracy: 0.9003
# Epoch 6/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2413 - accuracy: 0.9016 - val_loss: 0.3218 - val_accuracy: 0.8595
# Epoch 7/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2433 - accuracy: 0.9011 - val_loss: 0.2363 - val_accuracy: 0.9011
# Epoch 8/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2404 - accuracy: 0.9020 - val_loss: 0.2368 - val_accuracy: 0.9003
# Epoch 9/10
# 253/253 [==============================] - 16s 65ms/step - loss: 0.2318 - accuracy: 0.9063 - val_loss: 0.2591 - val_accuracy: 0.8838
# Epoch 10/10
# 253/253 [==============================] - 17s 67ms/step - loss: 0.2319 - accuracy: 0.9057 - val_loss: 0.2341 - val_accuracy: 0.9046
# RESULTADOS EN TEST:
# Pérdida en test: 0.2300824522972107
# Accuracy en test: 0.90625
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 75, 75, 3)        0
#  a)
#
#  tf.math.truediv_3 (TFOpLamb  (None, 75, 75, 3)        0
#  da)
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  dense_1 (Dense)             (None, 1)                 1921
#
# =================================================================
# Total params: 18,323,905
# Trainable params: 16,306,881
# Non-trainable params: 2,017,024
# _________________________________________________________________
# Epoch 10/45
# 253/253 [==============================] - 54s 170ms/step - loss: 0.3520 - accuracy: 0.8567 - val_loss: 1.0347 - val_accuracy: 0.6869
# Epoch 11/45
# 253/253 [==============================] - 40s 158ms/step - loss: 0.1677 - accuracy: 0.9339 - val_loss: 0.1121 - val_accuracy: 0.9610
# Epoch 12/45
# 253/253 [==============================] - 41s 161ms/step - loss: 0.1278 - accuracy: 0.9504 - val_loss: 0.1164 - val_accuracy: 0.9514
# Epoch 13/45
# 253/253 [==============================] - 41s 161ms/step - loss: 0.1130 - accuracy: 0.9575 - val_loss: 0.1082 - val_accuracy: 0.9636
# Epoch 14/45
# 253/253 [==============================] - 40s 159ms/step - loss: 0.0987 - accuracy: 0.9644 - val_loss: 0.1549 - val_accuracy: 0.9376
# Epoch 15/45
# 253/253 [==============================] - 40s 159ms/step - loss: 0.0904 - accuracy: 0.9662 - val_loss: 0.2464 - val_accuracy: 0.9159
# Epoch 16/45
# 253/253 [==============================] - 40s 160ms/step - loss: 0.0826 - accuracy: 0.9695 - val_loss: 0.1750 - val_accuracy: 0.9480
# Epoch 17/45
# 253/253 [==============================] - 40s 159ms/step - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0
# 253/253 [==============================] - 41s 161ms/step - loss: 0.0322 - accuracy: 0.9886 - val_loss: 0.1163 - val_accuracy: 0.9592
# Epoch 36/45
# 253/253 [==============================] - 40s 160ms/step - loss: 0.0310 - accuracy: 0.9887 - val_loss: 0.1285 - val_accuracy: 0.9592
# Epoch 37/45
# 253/253 [==============================] - 40s 160ms/step - loss: 0.0268 - accuracy: 0.9907 - val_loss: 0.1404 - val_accuracy: 0.9592
# Epoch 38/45
# 253/253 [==============================] - 40s 157ms/step - loss: 0.0272 - accuracy: 0.9888 - val_loss: 0.1842 - val_accuracy: 0.9471
# Epoch 39/45
# 253/253 [==============================] - 40s 156ms/step - loss: 0.0297 - accuracy: 0.9880 - val_loss: 0.1486 - val_accuracy: 0.9636
# Epoch 40/45
# 253/253 [==============================] - 40s 157ms/step - loss: 0.0250 - accuracy: 0.9902 - val_loss: 0.1051 - val_accuracy: 0.9705
# Epoch 41/45
# 253/253 [==============================] - 40s 156ms/step - loss: 0.0292 - accuracy: 0.9896 - val_loss: 0.1451 - val_accuracy: 0.9670
# Epoch 42/45
# 253/253 [==============================] - 40s 160ms/step - loss: 0.0218 - accuracy: 0.9908 - val_loss: 0.1192 - val_accuracy: 0.9670
# Epoch 43/45
# 253/253 [==============================] - 40s 156ms/step - loss: 0.0245 - accuracy: 0.9905 - val_loss: 0.1456 - val_accuracy: 0.9662
# Epoch 44/45
# 253/253 [==============================] - 40s 160ms/step - loss: 0.0223 - accuracy: 0.9912 - val_loss: 0.1158 - val_accuracy: 0.9636
# Epoch 45/45
# 253/253 [==============================] - 40s 159ms/step - loss: 0.0202 - accuracy: 0.9923 - val_loss: 0.1487 - val_accuracy: 0.9636
# RESULTADOS EN TEST:
# Pérdida en test: 0.10975278168916702
# Accuracy en test: 0.97265625

# %%
densenet = cargaDenseNet('densenet121')
densenet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 1s 0us/step
# 29097984/29084464 [==============================] - 1s 0us/step
# Model: "densenet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 75, 75, 3)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 81, 81, 3)   0           ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 38, 38, 64)   9408        ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 38, 38, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 38, 38, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 40, 40, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 19, 19, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 19, 19, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 19, 19, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 19, 19, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 19, 19, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 19, 19, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 19, 19, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 19, 19, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 19, 19, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 19, 19, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 19, 19, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 19, 19, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 19, 19, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 19, 19, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 19, 19, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 19, 19, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 19, 19, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 19, 19, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 19, 19, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 19, 19, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 19, 19, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 19, 19, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 19, 19, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 19, 19, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 19, 19, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 19, 19, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 19, 19, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 19, 19, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 19, 19, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 19, 19, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 19, 19, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 19, 19, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 19, 19, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 19, 19, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 19, 19, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 19, 19, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 19, 19, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 19, 19, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 19, 19, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 19, 19, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 19, 19, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 19, 19, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 19, 19, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 19, 19, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 19, 19, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 19, 19, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 9, 9, 128)    0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 9, 9, 128)   512         ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 9, 9, 128)   0           ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 9, 9, 128)    16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 9, 9, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 9, 9, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 9, 9, 32)     36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 9, 9, 160)   0           ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 9, 9, 160)   640         ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 9, 9, 160)   0           ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 9, 9, 128)    20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 9, 9, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 9, 9, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 9, 9, 32)     36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 9, 9, 192)   0           ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 9, 9, 192)   768         ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 9, 9, 192)   0           ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 9, 9, 128)    24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 9, 9, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 9, 9, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 9, 9, 32)     36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None,